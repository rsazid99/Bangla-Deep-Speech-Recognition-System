# %%
import argparse
import json
import os
from pathlib import Path
import sys
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dropout, TimeDistributed, Dense, Activation, Embedding
import numpy as np

from model import build_model, save_weights, load_weights
from train import train, read_batches, TrainLogger
# Out:
# Using TensorFlow backend.

# %%
MODEL_DIR = './model'
DATA_DIR = './data'
LOG_DIR = './logs'
MODEL_DIR = './model'

BATCH_SIZE = 100
SEQ_LENGTH = 64

# %%
if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
with open(os.path.join(DATA_DIR, "cleandataTrain.txt"), 'r') as data_file:
    text = data_file.read()
    train(text, 100, 10, False)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (1000, 64, 512)           33280
# _________________________________________________________________
# lstm_1 (LSTM)                (1000, 64, 256)           787456
# _________________________________________________________________
# dropout_1 (Dropout)          (1000, 64, 256)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (1000, 64, 256)           525312
# _________________________________________________________________
# dropout_2 (Dropout)          (1000, 64, 256)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (1000, 64, 256)           525312
# _________________________________________________________________
# dropout_3 (Dropout)          (1000, 64, 256)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (1000, 64, 65)            16705
# _________________________________________________________________
# activation_1 (Activation)    (1000, 64, 65)            0
# =================================================================
# Total params: 1,888,065
# Trainable params: 1,888,065
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/100
# loss: 4.174074172973633 and accuracy: 0.01614062488079071
#
# Epoch 2/100
# loss: 2.637857437133789 and accuracy: 0.26142188906669617
#
# Epoch 3/100
# loss: 2.200429677963257 and accuracy: 0.3810156285762787
#
# Epoch 4/100
# loss: 1.9769117832183838 and accuracy: 0.4397031366825104
#
# Epoch 5/100
# loss: 1.868951439857483 and accuracy: 0.4675624966621399
#
# Epoch 6/100
# loss: 1.7895410060882568 and accuracy: 0.488156259059906
#
# Epoch 7/100
# loss: 1.7544209957122803 and accuracy: 0.4948437511920929
#
# Epoch 8/100
# loss: 1.7178924083709717 and accuracy: 0.5046250224113464
#
# Epoch 9/100
# loss: 1.6876609325408936 and accuracy: 0.5121250152587891
#
# Epoch 10/100
# Saved checkpoint to weights.10.h5
# loss: 1.6738930940628052 and accuracy: 0.5142655968666077
#
# Epoch 11/100
# loss: 1.6492276191711426 and accuracy: 0.5206093788146973
#
# Epoch 12/100
# loss: 1.6531466245651245 and accuracy: 0.5211406350135803
#
# Epoch 13/100
# loss: 1.640228033065796 and accuracy: 0.5229843854904175
#
# Epoch 14/100
# loss: 1.6345752477645874 and accuracy: 0.5246718525886536
#
# Epoch 15/100
# loss: 1.6036540269851685 and accuracy: 0.5332343578338623
#
# Epoch 16/100
# loss: 1.601607322692871 and accuracy: 0.5291093587875366
#
# Epoch 17/100
# loss: 1.5833100080490112 and accuracy: 0.5374218821525574
#
# Epoch 18/100
# loss: 1.5701862573623657 and accuracy: 0.5399843454360962
#
# Epoch 19/100
# loss: 1.5725094079971313 and accuracy: 0.5397343635559082
#
# Epoch 20/100
# Saved checkpoint to weights.20.h5
# loss: 1.576945424079895 and accuracy: 0.5390937328338623
#
# Epoch 21/100
# loss: 1.5725218057632446 and accuracy: 0.5389687418937683
#
# Epoch 22/100
# loss: 1.5646005868911743 and accuracy: 0.5378749966621399
#
# Epoch 23/100
# loss: 1.5590068101882935 and accuracy: 0.5415937304496765
#
# Epoch 24/100
# loss: 1.5583802461624146 and accuracy: 0.5443906188011169
#
# Epoch 25/100
# loss: 1.550479769706726 and accuracy: 0.5444843769073486
#
# Epoch 26/100
# loss: 1.5445291996002197 and accuracy: 0.5459374785423279
#
# Epoch 27/100
# loss: 1.5465717315673828 and accuracy: 0.5460625290870667
#
# Epoch 28/100
# loss: 1.5350558757781982 and accuracy: 0.5484687685966492
#
# Epoch 29/100
# loss: 1.5383638143539429 and accuracy: 0.5470781326293945
#
# Epoch 30/100
# Saved checkpoint to weights.30.h5
# loss: 1.5401874780654907 and accuracy: 0.5483281016349792
#
# Epoch 31/100
# loss: 1.5425487756729126 and accuracy: 0.5472656488418579
#
# Epoch 32/100
# loss: 1.5255411863327026 and accuracy: 0.5504531264305115
#
# Epoch 33/100
# loss: 1.5360007286071777 and accuracy: 0.5465781092643738
#
# Epoch 34/100
# loss: 1.541067123413086 and accuracy: 0.5465937256813049
#
# Epoch 35/100
# loss: 1.5218638181686401 and accuracy: 0.5521875023841858
#
# Epoch 36/100
# loss: 1.533705711364746 and accuracy: 0.5484843850135803
#
# Epoch 37/100
# loss: 1.516997218132019 and accuracy: 0.5521718859672546
#
# Epoch 38/100
# loss: 1.5269453525543213 and accuracy: 0.5504375100135803
#
# Epoch 39/100
# loss: 1.517989993095398 and accuracy: 0.5531718730926514
#
# Epoch 40/100
# Saved checkpoint to weights.40.h5
# loss: 1.5286909341812134 and accuracy: 0.550000011920929
#
# Epoch 41/100
# loss: 1.5191904306411743 and accuracy: 0.5514218807220459
#
# Epoch 42/100
# loss: 1.5271474123001099 and accuracy: 0.5501718521118164
#
# Epoch 43/100
# loss: 1.5078879594802856 and accuracy: 0.5525156259536743
#
# Epoch 44/100
# loss: 1.509418249130249 and accuracy: 0.5529531240463257
#
# Epoch 45/100
# loss: 1.5185139179229736 and accuracy: 0.5506874918937683
#
# Epoch 46/100
# loss: 1.5052478313446045 and accuracy: 0.5562343597412109
#
# Epoch 47/100
# loss: 1.5048174858093262 and accuracy: 0.5548906326293945
#
# Epoch 48/100
# loss: 1.5042442083358765 and accuracy: 0.5569218993186951
#
# Epoch 49/100
# loss: 1.4998600482940674 and accuracy: 0.5574530959129333
#
# Epoch 50/100
# Saved checkpoint to weights.50.h5
# loss: 1.505142331123352 and accuracy: 0.5569999814033508
#
# Epoch 51/100
# loss: 1.5044811964035034 and accuracy: 0.5564218759536743
#
# Epoch 52/100
# loss: 1.5043596029281616 and accuracy: 0.5543437600135803
#
# Epoch 53/100
# loss: 1.4931756258010864 and accuracy: 0.5595781207084656
#
# Epoch 54/100
# loss: 1.4926533699035645 and accuracy: 0.559640645980835
#
# Epoch 55/100
# loss: 1.4911245107650757 and accuracy: 0.5614687204360962
#
# Epoch 56/100
# loss: 1.4945149421691895 and accuracy: 0.5593906044960022
#
# Epoch 57/100
# loss: 1.5047515630722046 and accuracy: 0.5553281307220459
#
# Epoch 58/100
# loss: 1.4801172018051147 and accuracy: 0.5636562705039978
#
# Epoch 59/100
# loss: 1.4933290481567383 and accuracy: 0.5591718554496765
#
# Epoch 60/100
# Saved checkpoint to weights.60.h5
# loss: 1.4883289337158203 and accuracy: 0.561453104019165
#
# Epoch 61/100
# loss: 1.4794865846633911 and accuracy: 0.5631093978881836
#
# Epoch 62/100
# loss: 1.49468994140625 and accuracy: 0.5564062595367432
#
# Epoch 63/100
# loss: 1.4750878810882568 and accuracy: 0.563281238079071
#
# Epoch 64/100
# loss: 1.4842209815979004 and accuracy: 0.5623593926429749
#
# Epoch 65/100
# loss: 1.4847412109375 and accuracy: 0.5611093640327454
#
# Epoch 66/100
# loss: 1.4726214408874512 and accuracy: 0.5665781497955322
#
# Epoch 67/100
# loss: 1.482081651687622 and accuracy: 0.5601406097412109
#
# Epoch 68/100
# loss: 1.4896992444992065 and accuracy: 0.5573750138282776
#
# Epoch 69/100
# loss: 1.4932383298873901 and accuracy: 0.55859375
#
# Epoch 70/100
# Saved checkpoint to weights.70.h5
# loss: 1.4836757183074951 and accuracy: 0.5609843730926514
#
# Epoch 71/100
# loss: 1.4770944118499756 and accuracy: 0.5616250038146973
#
# Epoch 72/100
# loss: 1.480617642402649 and accuracy: 0.5619843602180481
#
# Epoch 73/100
# loss: 1.4848655462265015 and accuracy: 0.5602187514305115
#
# Epoch 74/100
# loss: 1.4828814268112183 and accuracy: 0.5603437423706055
#
# Epoch 75/100
# loss: 1.482230544090271 and accuracy: 0.560546875
#
# Epoch 76/100
# loss: 1.480867862701416 and accuracy: 0.5630000233650208
#
# Epoch 77/100
# loss: 1.475337266921997 and accuracy: 0.5633437633514404
#
# Epoch 78/100
# loss: 1.47518789768219 and accuracy: 0.5633906126022339
#
# Epoch 79/100
# loss: 1.480804204940796 and accuracy: 0.5633593797683716
#
# Epoch 80/100
# Saved checkpoint to weights.80.h5
# loss: 1.4698090553283691 and accuracy: 0.5637031197547913
#
# Epoch 81/100
# loss: 1.4790035486221313 and accuracy: 0.5643125176429749
#
# Epoch 82/100
# loss: 1.484766960144043 and accuracy: 0.5636875033378601
#
# Epoch 83/100
# loss: 1.476813554763794 and accuracy: 0.563156247138977
#
# Epoch 84/100
# loss: 1.4769008159637451 and accuracy: 0.5625468492507935
#
# Epoch 85/100
# loss: 1.475726842880249 and accuracy: 0.5646718740463257
#
# Epoch 86/100
# loss: 1.4691237211227417 and accuracy: 0.5640468597412109
#
# Epoch 87/100
# loss: 1.4731025695800781 and accuracy: 0.5627655982971191
#
# Epoch 88/100
# loss: 1.4854795932769775 and accuracy: 0.5604375004768372
#
# Epoch 89/100
# loss: 1.481740117073059 and accuracy: 0.5621562600135803
#
# Epoch 90/100
# Saved checkpoint to weights.90.h5
# loss: 1.478663682937622 and accuracy: 0.5609843730926514
#
# Epoch 91/100
# loss: 1.4723902940750122 and accuracy: 0.564203143119812
#
# Epoch 92/100
# loss: 1.4732117652893066 and accuracy: 0.5645468831062317
#
# Epoch 93/100
# loss: 1.4852429628372192 and accuracy: 0.5606562495231628
#
# Epoch 94/100
# loss: 1.4763723611831665 and accuracy: 0.5652655959129333
#
# Epoch 95/100
# loss: 1.4757894277572632 and accuracy: 0.5630156397819519
#
# Epoch 96/100
# loss: 1.4763575792312622 and accuracy: 0.5621093511581421
#
# Epoch 97/100
# loss: 1.4698078632354736 and accuracy: 0.5656718611717224
#
# Epoch 98/100
# loss: 1.482229471206665 and accuracy: 0.5637031197547913
#
# Epoch 99/100
# loss: 1.472317099571228 and accuracy: 0.5634218454360962
#
# Epoch 100/100

# %%
lo = []

# %%
for i in range(5):
    lo.append(i)
print(lo[1])
